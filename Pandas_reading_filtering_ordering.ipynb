# %%
import pandas as pd

# %%
pd.read_csv(r'C:\Users\Rini\Documents\countries of the world.csv')
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
# pd.read_csv(r'C:\Users\Rini\Documents\countries of the world.txt',sep='\t')
pd.read_table(r'C:\Users\Rini\Documents\countries of the world.txt')
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
pd.read_json(r'C:\Users\Rini\Documents\json_sample.json')
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
pd.read_excel(r'C:\Users\Rini\Documents\world_population_excel_workbook.xlsx',sheet_name='Sheet1')
# Out:
#      Rank CCA3                           Country              Capital
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda       Saint Johnâ€™s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
# pd.set_option('display.max.rows',255)
# pd.set_option('display.max.columns',45)

# %%
df = pd.read_csv(r'C:\Users\Rini\Documents\countries of the world.csv')
df
# Out:
#                                Country                               Region
# 0                         Afghanistan         ASIA (EX. NEAR EAST)
# 1                             Albania   EASTERN EUROPE
# 2                             Algeria   NORTHERN AFRICA
# 3                      American Samoa   OCEANIA
# 4                             Andorra   WESTERN EUROPE
# 5                              Angola   SUB-SAHARAN AFRICA
# 6                            Anguilla               LATIN AMER. & CARIB
# 7                   Antigua & Barbuda               LATIN AMER. & CARIB
# 8                           Argentina               LATIN AMER. & CARIB
# 9                             Armenia                  C.W. OF IND. STATES
# 10                              Aruba               LATIN AMER. & CARIB
# 11                          Australia   OCEANIA
# 12                            Austria   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  227 non-null    object
#  1   Region   227 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df.shape
# Out:
# (227, 2)

# %%
df.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df.tail(10)
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
df['Country']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                        American Samoa
# 4                               Andorra
# 5                                Angola
# 6                              Anguilla
# 7                     Antigua & Barbuda
# 8                             Argentina
# 9                               Armenia
# 10                                Aruba
# 11                            Australia
# 12                              Austria
# 13                           Azerbaijan
# 14                         Bahamas, The
# 15                              Bahrain
# 16                           Bangladesh
# 17                             Barbados
# 18                              Belarus
# 19                              Belgium
# 20                               Belize
# 21                                Benin
# 22                              Bermuda
# ...

# %%
df.loc[224]
# Out:
# Country                                 Yemen
# Region     NEAR EAST
# Name: 224, dtype: object

# %%
df.iloc[224]
# Out:
# Country                                 Yemen
# Region     NEAR EAST
# Name: 224, dtype: object

# %%
df1 = pd.read_csv(r'C:\Users\Rini\Documents\world_population.csv')
df1
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
df1[df1['Rank']<=12]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 102    11  JPN          Japan             Tokyo           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
specific_countries = ['India','Canada','Brazil']
df1[df1['Country'].isin(specific_countries)]
# Out:
#     Rank CCA3 Country    Capital      Continent  2022 Population  \
# 27     7  BRA  Brazil   Brasilia  South America     2.153135e+08
# 35    39  CAN  Canada     Ottawa  North America     3.845433e+07
# 92     2  IND   India  New Delhi           Asia     1.417173e+09
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 27     2.131963e+08     2.051882e+08     1.963535e+08     1.758737e+08
# 35     3.788870e+07     3.573213e+07     3.396341e+07     3.068331e+07
# 92     1.396387e+09     1.322867e+09     1.240614e+09     1.059634e+09
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 27      150706446.0      122288383.0       96369875.0   8515767.0
# 35       27657204.0       24511510.0       21434577.0   9984670.0
# 92              NaN              NaN      557501301.0   3287590.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 27            25.2841       1.0046                         2.70
# ...

# %%
df1[df1['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df2 = df1.set_index('Country')
df2
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
df2.filter(items=['Continent','CCA3','Rank'])
# Out:
#                                       Continent CCA3  Rank
# Country
# Afghanistan                                Asia  AFG    36
# Albania                                  Europe  ALB   138
# Algeria                                  Africa  DZA    34
# American Samoa                          Oceania  ASM   213
# Andorra                                  Europe  AND   203
# Angola                                   Africa  AGO    42
# Anguilla                          North America  AIA   224
# Antigua and Barbuda               North America  ATG   201
# Argentina                         South America  ARG    33
# Armenia                                    Asia  ARM   140
# Aruba                             North America  ABW   198
# Australia                               Oceania  AUS    55
# Austria                                  Europe  AUT    99
# Azerbaijan                                 Asia  AZE    91
# Bahamas                           North America  BHS   176
# ...

# %%
df2.filter(items=['Afghanistan','Cambodia','Egypt'],axis=0)
# Out:
#              Rank CCA3     Capital Continent  2022 Population  \
# Country
# Afghanistan    36  AFG       Kabul      Asia       41128771.0
# Cambodia       73  KHM  Phnom Penh      Asia       16767842.0
# Egypt          14  EGY       Cairo    Africa      110990103.0
#
#              2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan       38972230.0       33753499.0       28189672.0
# Cambodia          16396860.0       15417523.0       14363532.0
# Egypt            107465134.0       97723799.0       87252413.0
#
#              2000 Population  1990 Population  1980 Population  \
# Country
# Afghanistan       19542982.0       10694796.0       12486631.0
# Cambodia          12118841.0        8910808.0        6198959.0
# Egypt             71371371.0       57214630.0       43748556.0
#
#              1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# Country
# Afghanistan       10752971.0    652230.0            63.0587       1.0257
# ...

# %%
df2.filter(like='United',axis=0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country
# United Arab Emirates                9441129.0        9287289.0
# United Kingdom                     67508936.0       67059474.0
# United States                     338289857.0      335942003.0
# United States Virgin Islands          99465.0         100442.0
#
#                               2015 Population  2010 Population  \
# Country
# United Arab Emirates                8916899.0        8481771.0
# United Kingdom                     65224364.0       62760039.0
# ...

# %%
df2.loc['India']
# Out:
# Rank                                      2
# CCA3                                    IND
# Capital                           New Delhi
# Continent                              Asia
# 2022 Population                1417173173.0
# 2020 Population                1396387127.0
# 2015 Population                1322866505.0
# 2010 Population                1240613620.0
# 2000 Population                1059633675.0
# 1990 Population                         NaN
# 1980 Population                         NaN
# 1970 Population                 557501301.0
# Area (km²)                        3287590.0
# Density (per km²)                  431.0675
# Growth Rate                          1.0068
# World Population Percentage           17.77
# Name: India, dtype: object

# %%
df2.iloc[8]
# Out:
# Rank                                      33
# CCA3                                     ARG
# Capital                         Buenos Aires
# Continent                      South America
# 2022 Population                   45510318.0
# 2020 Population                   45036032.0
# 2015 Population                   43257065.0
# 2010 Population                   41100123.0
# 2000 Population                   37070774.0
# 1990 Population                   32637657.0
# 1980 Population                   28024803.0
# 1970 Population                   23842803.0
# Area (km²)                         2780400.0
# Density (per km²)                    16.3683
# Growth Rate                           1.0052
# World Population Percentage             0.57
# Name: Argentina, dtype: object

# %%
df1[df1['Rank']<=12].sort_values(by='Rank',ascending=False)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 102    11  JPN          Japan             Tokyo           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df1[df1['Rank']<=12].sort_values(by=['Continent','Country'],ascending=[False,True])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 131    10  MEX         Mexico       Mexico City  North America
# 221     3  USA  United States  Washington, D.C.  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 102    11  JPN          Japan             Tokyo           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...
